# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rc("figure", figsize=(12, 12))
plt.rc("font", family="monospace", weight="bold", size=10)

# %%
m_net="C:\\Users\\Engineering\\Desktop\\data_file\\microsoft_stock_synthetic.csv"

# %%
msft_sk=pd.read_csv(m_net)

# %%
msft_sk.isna().sum()
# Out:
# Date                  0
# Open                  0
# High                  0
# Low                   0
# Close                 0
# Volume                0
# AdjustedClose         0
# Dividend              0
# SplitCoefficient      0
# DailyReturnPercent    0
# dtype: int64

# %%
msft_sk.dtypes
# Out:
# Date                   object
# Open                  float64
# High                  float64
# Low                   float64
# Close                 float64
# Volume                  int64
# AdjustedClose         float64
# Dividend              float64
# SplitCoefficient      float64
# DailyReturnPercent    float64
# dtype: object

# %%
msft_sk
# Out:
#            Date    Open    High     Low   Close    Volume  AdjustedClose  \
# 0    2020-01-01  150.56  150.61  150.01  150.14   7878334         151.20
# 1    2020-01-02  149.83  149.89  149.39  149.64   2780798         150.01
# 2    2020-01-03  149.32  150.22  148.76  150.03  11714555         151.22
# 3    2020-01-04  151.86  152.53  151.67  151.75  24082477         152.38
# 4    2020-01-05  151.89  153.84  151.13  152.63  43187302         153.35
# ..          ...     ...     ...     ...     ...       ...            ...
# 995  2022-09-22  168.18  169.63  166.38  169.33  28600409         172.67
# 996  2022-09-23  167.64  167.85  166.11  166.68  31261801         164.45
# 997  2022-09-24  164.79  166.07  163.44  164.65  24062478         166.27
# 998  2022-09-25  162.69  162.92  160.86  161.53  32154991         161.43
# 999  2022-09-26  160.50  162.40  160.22  162.01  11829124         159.88
#
#      Dividend  SplitCoefficient  DailyReturnPercent
# ...

# %%
pd.date_range("2000-01-01", periods=1000)
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20',
#                '2002-09-21', '2002-09-22', '2002-09-23', '2002-09-24',
#                '2002-09-25', '2002-09-26'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
msft_sk_Date= msft_sk.set_index(['Date'])

# %%
msft_sk_Date
# Out:
#               Open    High     Low   Close    Volume  AdjustedClose  Dividend  \
# Date
# 2020-01-01  150.56  150.61  150.01  150.14   7878334         151.20      0.00
# 2020-01-02  149.83  149.89  149.39  149.64   2780798         150.01      0.00
# 2020-01-03  149.32  150.22  148.76  150.03  11714555         151.22      0.00
# 2020-01-04  151.86  152.53  151.67  151.75  24082477         152.38      0.00
# 2020-01-05  151.89  153.84  151.13  152.63  43187302         153.35      0.00
# ...            ...     ...     ...     ...       ...            ...       ...
# 2022-09-22  168.18  169.63  166.38  169.33  28600409         172.67      0.00
# 2022-09-23  167.64  167.85  166.11  166.68  31261801         164.45      0.00
# 2022-09-24  164.79  166.07  163.44  164.65  24062478         166.27      0.00
# 2022-09-25  162.69  162.92  160.86  161.53  32154991         161.43      0.00
# 2022-09-26  160.50  162.40  160.22  162.01  11829124         159.88      0.29
#
# ...

# %%
msft_sk_Date.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1.000000e+03
# mean    159.032870   160.035370   158.047990   159.018200  2.573578e+07
# std      12.146515    12.163377    12.163039    12.153175  1.440198e+07
# min     134.680000   135.230000   133.090000   134.570000  1.172369e+06
# 25%     149.115000   150.027500   147.635000   149.020000  1.285394e+07
# 50%     161.500000   162.620000   160.655000   161.595000  2.642298e+07
# 75%     169.275000   170.252500   168.362500   169.320000  3.831272e+07
# max     185.030000   186.330000   183.120000   183.560000  4.998434e+07
#
#        AdjustedClose     Dividend  SplitCoefficient  DailyReturnPercent
# count    1000.000000  1000.000000       1000.000000         1000.000000
# mean      159.069400     0.040640          1.023000            0.011340
# std        12.283942     0.232261          0.237755            0.854483
# ...

# %%
data_2020=msft_sk[msft_sk["Date"].str.startswith('2020')]

# %%
data_2020
# Out:
#            Date    Open    High     Low   Close    Volume  AdjustedClose  \
# 0    2020-01-01  150.56  150.61  150.01  150.14   7878334         151.20
# 1    2020-01-02  149.83  149.89  149.39  149.64   2780798         150.01
# 2    2020-01-03  149.32  150.22  148.76  150.03  11714555         151.22
# 3    2020-01-04  151.86  152.53  151.67  151.75  24082477         152.38
# 4    2020-01-05  151.89  153.84  151.13  152.63  43187302         153.35
# ..          ...     ...     ...     ...     ...       ...            ...
# 361  2020-12-27  167.64  168.17  167.40  167.52  47040361         166.21
# 362  2020-12-28  166.38  168.09  166.08  167.51  24873492         166.81
# 363  2020-12-29  168.79  169.14  166.89  168.81  38309425         170.49
# 364  2020-12-30  170.03  170.31  170.01  170.26  15917504         167.75
# 365  2020-12-31  170.78  172.07  169.62  170.25   6032304         166.99
#
#      Dividend  SplitCoefficient  DailyReturnPercent
# ...

# %%
data_2021=msft_sk[msft_sk["Date"].str.startswith('2021')]
data_2021
# Out:
#            Date    Open    High     Low   Close    Volume  AdjustedClose  \
# 366  2021-01-01  170.02  170.28  168.21  169.93  23249936         167.36
# 367  2021-01-02  171.63  172.50  170.18  171.33  26684537         172.59
# 368  2021-01-03  170.08  170.64  168.31  168.39  42552234         169.18
# 369  2021-01-04  169.92  170.88  169.74  170.18  29134372         168.13
# 370  2021-01-05  170.70  172.30  169.11  172.27  48873495         171.30
# ..          ...     ...     ...     ...     ...       ...            ...
# 726  2021-12-27  140.72  142.37  140.12  141.06  38427311         139.57
# 727  2021-12-28  139.44  140.16  137.92  139.13  15715372         138.93
# 728  2021-12-29  137.34  137.57  137.04  137.49  32837306         137.48
# 729  2021-12-30  135.71  136.44  135.29  135.58  42394045         137.23
# 730  2021-12-31  136.54  138.39  136.19  137.92  33551919         138.00
#
#      Dividend  SplitCoefficient  DailyReturnPercent   20_days   50_days  \
# ...

# %%
data_2020.groupby('Open')['AdjustedClose'].value_counts()
# Out:
# Open    AdjustedClose
# 138.53  140.54           1
# 138.77  137.65           1
# 138.80  138.53           1
# 138.97  139.54           1
# 139.40  136.79           1
#                         ..
# 178.24  175.03           1
# 178.28  176.01           1
# 179.01  174.69           1
# 179.02  179.33           1
# 179.15  179.17           1
# Name: AdjustedClose, Length: 366, dtype: int64

# %%
msft_sk.Close.plot(title="closing price")
msft_sk['20_days']= msft_sk['Close'].rolling(window=20).mean()
msft_sk['50_days']= msft_sk['Close'].rolling(window=50).mean()
msft_sk['100_days']= msft_sk['Close'].rolling(window=100).mean()
plt.plot(msft_sk['20_days'], label= '20-days MA')
plt.plot(msft_sk['50_days'], label= '50-days MA')
plt.plot(msft_sk['100_days'], label= '100-days MA')
plt.legend()

# %%
# daily Returns
msft_sk['Return']=msft_sk['Close'].pct_change()

# %%
msft_sk
# Out:
#            Date    Open    High     Low   Close    Volume  AdjustedClose  \
# 0    2020-01-01  150.56  150.61  150.01  150.14   7878334         151.20
# 1    2020-01-02  149.83  149.89  149.39  149.64   2780798         150.01
# 2    2020-01-03  149.32  150.22  148.76  150.03  11714555         151.22
# 3    2020-01-04  151.86  152.53  151.67  151.75  24082477         152.38
# 4    2020-01-05  151.89  153.84  151.13  152.63  43187302         153.35
# ..          ...     ...     ...     ...     ...       ...            ...
# 995  2022-09-22  168.18  169.63  166.38  169.33  28600409         172.67
# 996  2022-09-23  167.64  167.85  166.11  166.68  31261801         164.45
# 997  2022-09-24  164.79  166.07  163.44  164.65  24062478         166.27
# 998  2022-09-25  162.69  162.92  160.86  161.53  32154991         161.43
# 999  2022-09-26  160.50  162.40  160.22  162.01  11829124         159.88
#
#      Dividend  SplitCoefficient  DailyReturnPercent   20_days   50_days  \
# ...

# %%
# mean Returns in 300 days

msft_sk['Return'].rolling(window=300).mean().plot()
# Out:
# <AxesSubplot:>

# %%
# volatility
volatility=msft_sk['Return'].std() * np.sqrt(1000)
volatility
# Out:
# 0.2703534167681074

# %%
msft_sk["cumulative_return"]=(1 + msft_sk['Return']).cumprod()

# %%
msft_sk["cumulative_return"]
# Out:
# 0           NaN
# 1      0.996670
# 2      0.999267
# 3      1.010723
# 4      1.016585
#          ...
# 995    1.127814
# 996    1.110164
# 997    1.096643
# 998    1.075863
# 999    1.079060
# Name: cumulative_return, Length: 1000, dtype: float64

# %%
msft_sk
# Out:
#            Date    Open    High     Low   Close    Volume  AdjustedClose  \
# 0    2020-01-01  150.56  150.61  150.01  150.14   7878334         151.20
# 1    2020-01-02  149.83  149.89  149.39  149.64   2780798         150.01
# 2    2020-01-03  149.32  150.22  148.76  150.03  11714555         151.22
# 3    2020-01-04  151.86  152.53  151.67  151.75  24082477         152.38
# 4    2020-01-05  151.89  153.84  151.13  152.63  43187302         153.35
# ..          ...     ...     ...     ...     ...       ...            ...
# 995  2022-09-22  168.18  169.63  166.38  169.33  28600409         172.67
# 996  2022-09-23  167.64  167.85  166.11  166.68  31261801         164.45
# 997  2022-09-24  164.79  166.07  163.44  164.65  24062478         166.27
# 998  2022-09-25  162.69  162.92  160.86  161.53  32154991         161.43
# 999  2022-09-26  160.50  162.40  160.22  162.01  11829124         159.88
#
#      Dividend  SplitCoefficient  DailyReturnPercent   20_days   50_days  \
# ...

# %%
msft_sk['Close'].idxmax()
# Out:
# 489

# %%
msft_sk['Close'].idxmin()
# Out:
# 735

# %%
# risk analysis
var_95= np.percentile(msft_sk['Return'].dropna().astype('int64'), 5)
var_95
# Out:
# 0.0

# %%
msft_sk['Close'].astype('int64')
# Out:
# 0      150
# 1      149
# 2      150
# 3      151
# 4      152
#       ...
# 995    169
# 996    166
# 997    164
# 998    161
# 999    162
# Name: Close, Length: 1000, dtype: int64

# %%
msft_sk['Close'].cumprod?
# Out:
# Object `cumprod` not found.

# %%
s_300=msft_sk["cumulative_return"].pct_change().rolling(window=700,).std().dropna()

# %%
s_300.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression

# %%
x= np.arange(len(msft_sk)).reshape(-1,1)  #Time as feature
y= msft_sk['Close'].values
model= LinearRegression().fit(x,y)

# %%
model.predict(x)
# Out:
# array([160.4832248 , 160.48029181, 160.47735883, 160.47442585,
#        160.47149286, 160.46855988, 160.4656269 , 160.46269392,
#        160.45976093, 160.45682795, 160.45389497, 160.45096199,
#        160.448029  , 160.44509602, 160.44216304, 160.43923006,
#        160.43629707, 160.43336409, 160.43043111, 160.42749813,
#        160.42456514, 160.42163216, 160.41869918, 160.4157662 ,
#        160.41283321, 160.40990023, 160.40696725, 160.40403427,
#        160.40110128, 160.3981683 , 160.39523532, 160.39230234,
#        160.38936935, 160.38643637, 160.38350339, 160.38057041,
#        160.37763742, 160.37470444, 160.37177146, 160.36883847,
#        160.36590549, 160.36297251, 160.36003953, 160.35710654,
#        160.35417356, 160.35124058, 160.3483076 , 160.34537461,
#        160.34244163, 160.33950865, 160.33657567, 160.33364268,
#        160.3307097 , 160.32777672, 160.32484374, 160.32191075,
#        160.31897777, 160.31604479, 160.31311181, 160.31017882,
# ...

# %%
plt.scatter(x,y, s= 10)

# %%
model
# Out:
# LinearRegression()

# %%
from scipy import stats
msft_sk["z_score"]= stats.zscore(msft_sk['Close'])
msft_sk= msft_sk[abs(msft_sk['z_score'])<3] #remove outlier beyond 3

# %%
msft_sk
# Out:
#            Date    Open    High     Low   Close    Volume  AdjustedClose  \
# 0    2020-01-01  150.56  150.61  150.01  150.14   7878334         151.20
# 1    2020-01-02  149.83  149.89  149.39  149.64   2780798         150.01
# 2    2020-01-03  149.32  150.22  148.76  150.03  11714555         151.22
# 3    2020-01-04  151.86  152.53  151.67  151.75  24082477         152.38
# 4    2020-01-05  151.89  153.84  151.13  152.63  43187302         153.35
# ..          ...     ...     ...     ...     ...       ...            ...
# 995  2022-09-22  168.18  169.63  166.38  169.33  28600409         172.67
# 996  2022-09-23  167.64  167.85  166.11  166.68  31261801         164.45
# 997  2022-09-24  164.79  166.07  163.44  164.65  24062478         166.27
# 998  2022-09-25  162.69  162.92  160.86  161.53  32154991         161.43
# 999  2022-09-26  160.50  162.40  160.22  162.01  11829124         159.88
#
#      Dividend  SplitCoefficient  DailyReturnPercent   20_days   50_days  \
# ...

# %%
x= np.arange(len(data_2020)).reshape(-1,1)  #Time as feature
y= data_2020['Close'].values
model= LinearRegression().fit(x,y)
pred_2021=model.predict(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-227-2e1d3cb7c985> in <module>
#       2 y= data_2020['Close'].values
#       3 model= LinearRegression().fit(x,y)
# ----> 4 pred_2021=model.predict(y)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     216         check_is_fitted(self)
#     217
# --> 218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#
# ...

# %%
pd.Series(pred_2021, dtype='int64')
# Out:
# 0      142.099873
# 1      142.191958
# 2      142.284043
# 3      142.376127
# 4      142.468212
#           ...
# 361    175.342498
# 362    175.434583
# 363    175.526668
# 364    175.618753
# 365    175.710837
# Length: 366, dtype: float64

# %%
data_2021.Close
# Out:
# 366    169.93
# 367    171.33
# 368    168.39
# 369    170.18
# 370    172.27
#         ...
# 726    141.06
# 727    139.13
# 728    137.49
# 729    135.58
# 730    137.92
# Name: Close, Length: 365, dtype: float64
